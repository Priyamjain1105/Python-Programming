# %% [markdown]
# # Conditional Statements

# %%
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
stri = "hwlloe world"
for i in stri:
    print(i)
# Out:
# h
# w
# l
# l
# o
# e
#
# w
# o
# r
# l
# d
