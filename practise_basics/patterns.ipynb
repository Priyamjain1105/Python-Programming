# %%
n=5
lst = []
for i in range(1,n+1):
    st = " "*(n-i)+"*"*i+ " "*(n-i)
    lst.append(st)
print(lst)
# Out:
# ['    *    ', '   **   ', '  ***  ', ' **** ', '*****']

# %%
lst = []
count  = 0
i = 1
n = 5
while(count<n):
    
    st = " "*(n-i)+"*"*(i)+ " "*(n-i)
    lst.append(st)
    i = i+2
    count = count+1
print(lst)
# Out:
# ['    *    ', '  ***  ', '*****', '*******', '*********']
